# %% [markdown]
# <a href="https://colab.research.google.com/github/Suphattha/data_viz/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# โหลดตาราง ตค57 กับ ตาราง พย57
# จากไฟล์ จัดซื้อ ตค57-ตค58
#
# จาก https://data.go.th/dataset/item_fadc318e-7743-4bc2-84d1-a19210a9bbd6

# %%
import pandas as pd

# %%
oct57 = pd.read_excel('/content/drive/My Drive/dataviz_2021_data/-.57-.58-1.xls',sheet_name=0,header=4,skipfooter=20)
oct57 = oct57.dropna()
oct57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %%
oct57.rename(columns={'Unnamed: 5':'ราคาเสนอ','Unnamed: 7':'ราคาซื้อ'})
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %% [markdown]
# ## การบ้าน 8 ทำ พย57 ให้เสร็จ

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = '/content/drive/My Drive/dataviz_2021_data'

# %%
file_path = os.path.join(path,'-.57-.58-1.xls') 
print(file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/-.57-.58-1.xls

# %%
Nov57 = pd.read_excel(file_path,sheet_name='พย.57',header=4,skipfooter=30)
Nov57 = Nov57.dropna()
Nov57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# 9      9  ...           เป็นผู้จำหน่าย
# 10    10  ...           เป็นผู้จำหน่าย
# 11    11  ...           เป็นผู้จำหน่าย
# 12    12  ...           เป็นผู้จำหน่าย
# 13    13  ...           เป็นผู้จำหน่าย
# 14    14  ...           เป็นผู้จำหน่าย
# 15    15  ...           เป็นผู้จำหน่าย
# 22    16  ...           เป็นผู้จำหน่าย
# 23    17  ...           เป็นผู้จำหน่าย
# 24    18  ...           เป็นผู้จำหน่าย
# 25    19  ...           เป็นผู้จำหน่าย
# 26    20  ...           เป็นผู้จำหน่าย
# 27    21  ...           เป็นผู้จำหน่าย
# 28    22  ...           เป็นผู้จำหน่าย
# 29    23  ...           เป็นผู้จำหน่าย
# ...

# %%
data_month = pd.concat([oct57,Nov57])
data_month
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# ...

# %%
data = data_month.rename(columns={'Unnamed: 5':'ราคาเสนอ','Unnamed: 7':'ราคาซื้อ'})
data
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# ...
